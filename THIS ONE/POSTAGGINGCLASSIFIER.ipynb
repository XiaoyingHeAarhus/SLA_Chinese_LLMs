# %%
# !pip install hanlp
# Out:
# Collecting hanlp
#   Using cached hanlp-2.1.3-py3-none-any.whl.metadata (13 kB)
# Collecting hanlp-common>=0.0.23 (from hanlp)
#   Using cached hanlp_common-0.0.23.tar.gz (28 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting hanlp-downloader (from hanlp)
#   Using cached hanlp_downloader-0.0.25.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting hanlp-trie>=0.0.4 (from hanlp)
#   Using cached hanlp_trie-0.0.5.tar.gz (6.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pynvml (from hanlp)
#   Using cached pynvml-13.0.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting sentencepiece>=0.1.91 (from hanlp)
#   Using cached sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting termcolor (from hanlp)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting toposort==1.5 (from hanlp)
#   Using cached toposort-1.5-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting torch>=1.6.0 (from hanlp)
#   Using cached torch-2.11.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: transformers>=4.1.1 in /opt/conda/lib/python3.12/site-packages (from hanlp) (4.47.0)
# Collecting phrasetree>=0.0.9 (from hanlp-common>=0.0.23->hanlp)
#   Using cached phrasetree-0.0.9.tar.gz (42 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch>=1.6.0->hanlp) (3.24.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch>=1.6.0->hanlp) (4.15.0)
# Requirement already satisfied: setuptools<82 in /opt/conda/lib/python3.12/site-packages (from torch>=1.6.0->hanlp) (80.9.0)
# Collecting sympy>=1.13.3 (from torch>=1.6.0->hanlp)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.6.0->hanlp)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=1.6.0->hanlp) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/conda/lib/python3.12/site-packages (from torch>=1.6.0->hanlp) (2026.2.0)
# Collecting cuda-toolkit==13.0.2 (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached cuda_toolkit-13.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting cuda-bindings<14,>=13.0.3 (from torch>=1.6.0->hanlp)
#   Using cached cuda_bindings-13.2.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Collecting nvidia-cudnn-cu13==9.19.0.56 (from torch>=1.6.0->hanlp)
#   Using cached nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparselt-cu13==0.8.0 (from torch>=1.6.0->hanlp)
#   Using cached nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting nvidia-nccl-cu13==2.28.9 (from torch>=1.6.0->hanlp)
#   Using cached nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5 (from torch>=1.6.0->hanlp)
#   Using cached nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting triton==3.6.0 (from torch>=1.6.0->hanlp)
#   Using cached triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cublas==13.1.0.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime==13.0.96.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufile==1.15.1.6.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand==10.4.0.35.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse==12.6.3.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.6.0->hanlp)
#   Using cached nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (1.8 kB)
# Collecting cuda-pathfinder~=1.1 (from cuda-bindings<14,>=13.0.3->torch>=1.6.0->hanlp)
#   Using cached cuda_pathfinder-1.5.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.6.0->hanlp)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (2026.1.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.12/site-packages (from transformers>=4.1.1->hanlp) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers>=4.1.1->hanlp) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=1.6.0->hanlp) (3.0.3)
# Collecting nvidia-ml-py>=12.0.0 (from pynvml->hanlp)
#   Using cached nvidia_ml_py-13.595.45-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->transformers>=4.1.1->hanlp) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->transformers>=4.1.1->hanlp) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->transformers>=4.1.1->hanlp) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->transformers>=4.1.1->hanlp) (2025.11.12)
# Using cached hanlp-2.1.3-py3-none-any.whl (654 kB)
# Using cached toposort-1.5-py2.py3-none-any.whl (7.6 kB)
# Using cached sentencepiece-0.2.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
# Using cached torch-2.11.0-cp312-cp312-manylinux_2_28_x86_64.whl (530.7 MB)
# Using cached cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl (366.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 5.3 MB/s  0:01:07m0:00:0100:02
# Downloading nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl (169.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 5.1 MB/s  0:00:32m0:00:0100:01
# Downloading nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl (196.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 5.0 MB/s  0:00:38m0:00:0100:02
# Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 5.9 MB/s  0:00:10m0:00:0100:01
# Downloading triton-3.6.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 5.3 MB/s  0:00:36m0:00:0100:01
# Downloading cuda_bindings-13.2.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 5.8 MB/s  0:00:01m0:00:0100:01
# Downloading cuda_pathfinder-1.5.0-py3-none-any.whl (49 kB)
# Downloading nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 5.2 MB/s  0:01:19m0:00:0100:02
# Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 4.5 MB/s  0:00:02m0:00:010:01
# Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 5.7 MB/s  0:00:15m0:00:0100:01
# Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 4.7 MB/s  0:00:00 eta 0:00:01
# Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 4.7 MB/s  0:00:43m0:00:0100:02
# Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.7 MB/s  0:00:00 eta 0:00:01
# Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 5.4 MB/s  0:00:11m0:00:0100:01
# Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 5.3 MB/s  0:00:38m0:00:0100:01
# Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 5.0 MB/s  0:00:29m0:00:0100:01
# Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 4.4 MB/s  0:00:09m0:00:0100:01
# Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.7 MB/s  0:00:00 eta 0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 2.9 MB/s  0:00:02m0:00:0100:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.3 MB/s  0:00:00m0:00:01
# Downloading pynvml-13.0.1-py3-none-any.whl (28 kB)
# Downloading nvidia_ml_py-13.595.45-py3-none-any.whl (51 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: hanlp-common, hanlp-trie, phrasetree, hanlp-downloader
#   Building wheel for hanlp-common (pyproject.toml) ... done
#   Created wheel for hanlp-common: filename=hanlp_common-0.0.23-py3-none-any.whl size=30893 sha256=3b3b03b217ad409fe5bffdf535e54235aa24b5f94ecc7ea9802bd2b57a222f8c
#   Stored in directory: /home/ucloud/.cache/pip/wheels/b8/22/2d/75d505250ca2b83d52998e97db4d3ed89315138752d2e22794
#   Building wheel for hanlp-trie (pyproject.toml) ... done
#   Created wheel for hanlp-trie: filename=hanlp_trie-0.0.5-py3-none-any.whl size=6884 sha256=14fb896f16fb0aa44ce6ee1c36144d4b1181e5e737ce5527ecb838a374874d8d
#   Stored in directory: /home/ucloud/.cache/pip/wheels/26/a2/e2/b2a458cadfb9ff912848b0e6205bfa5ac628daa5156ccac651
#   Building wheel for phrasetree (pyproject.toml) ... done
#   Created wheel for phrasetree: filename=phrasetree-0.0.9-py3-none-any.whl size=44275 sha256=f89098216654fa49a1afe1f3b3a4780f578e9767bfbb01b4f9b251325b0cd210
#   Stored in directory: /home/ucloud/.cache/pip/wheels/85/6c/77/51fc144dbf90ff2b9e898ce24082958e63388341de3567ace3
#   Building wheel for hanlp-downloader (pyproject.toml) ... done
#   Created wheel for hanlp-downloader: filename=hanlp_downloader-0.0.25-py3-none-any.whl size=13794 sha256=0143542e10e59b19e26338fb2da8febbed473ffae2e2643ce46f6b3d1a18e527
#   Stored in directory: /home/ucloud/.cache/pip/wheels/f6/59/2c/1373729f96160c9cded2968f6c33377aab5c95ba1002b559fd
# Successfully built hanlp-common hanlp-trie phrasetree hanlp-downloader
# Installing collected packages: toposort, phrasetree, nvidia-ml-py, nvidia-cusparselt-cu13, mpmath, cuda-toolkit, triton, termcolor, sympy, sentencepiece, pynvml, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, nvidia-cublas, networkx, hanlp-common, cuda-pathfinder, nvidia-cusparse, nvidia-cufft, nvidia-cudnn-cu13, hanlp-trie, hanlp-downloader, cuda-bindings, nvidia-cusolver, torch, hanlp
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33/33 [hanlp]m32/33 [hanlp]-cusolver]3]e]13]
# Successfully installed cuda-bindings-13.2.0 cuda-pathfinder-1.5.0 cuda-toolkit-13.0.2 hanlp-2.1.3 hanlp-common-0.0.23 hanlp-downloader-0.0.25 hanlp-trie-0.0.5 mpmath-1.3.0 networkx-3.6.1 nvidia-cublas-13.1.0.3 nvidia-cuda-cupti-13.0.85 nvidia-cuda-nvrtc-13.0.88 nvidia-cuda-runtime-13.0.96 nvidia-cudnn-cu13-9.19.0.56 nvidia-cufft-12.0.0.61 nvidia-cufile-1.15.1.6 nvidia-curand-10.4.0.35 nvidia-cusolver-12.0.4.66 nvidia-cusparse-12.6.3.3 nvidia-cusparselt-cu13-0.8.0 nvidia-ml-py-13.595.45 nvidia-nccl-cu13-2.28.9 nvidia-nvjitlink-13.0.88 nvidia-nvshmem-cu13-3.4.5 nvidia-nvtx-13.0.85 phrasetree-0.0.9 pynvml-13.0.1 sentencepiece-0.2.1 sympy-1.14.0 termcolor-3.3.0 toposort-1.5 torch-2.11.0 triton-3.6.0

# %%
import hanlp
print(hanlp.__version__)
# Out:
# 2.1.3

# %%
HanLP = hanlp.load(hanlp.pretrained.mtl.CLOSE_TOK_POS_NER_SRL_DEP_SDP_CON_ELECTRA_SMALL_ZH)
# Out:
# Downloading https://file.hankcs.com/hanlp/mtl/close_tok_pos_ner_srl_dep_sdp_con_electra_small_20210111_124159.zip to /home/ucloud/.hanlp/mtl/close_tok_pos_ner_srl_dep_sdp_con_electra_small_20210111_124159.zip
# 100% 114.3 MiB   1.0 MiB/s ETA:  0 s [=========================================]
# Decompressing /home/ucloud/.hanlp/mtl/close_tok_pos_ner_srl_dep_sdp_con_electra_small_20210111_124159.zip to /home/ucloud/.hanlp/mtl
# Downloading https://file.hankcs.com/hanlp/transformers/electra_zh_small_20210706_125427.zip to /home/ucloud/.hanlp/transformers/electra_zh_small_20210706_125427.zip
# 100%  41.2 KiB  20.6 KiB/s ETA:  0 s [=========================================]
# Decompressing /home/ucloud/.hanlp/transformers/electra_zh_small_20210706_125427.zip to /home/ucloud/.hanlp/transformers
# Downloading https://file.hankcs.com/corpus/char_table.json.zip to /home/ucloud/.hanlp/thirdparty/file.hankcs.com/corpus/char_table.json.zip
# 100%  19.4 KiB  19.4 KiB/s ETA:  0 s [=========================================]
# Decompressing /home/ucloud/.hanlp/thirdparty/file.hankcs.com/corpus/char_table.json.zip to /home/ucloud/.hanlp/thirdparty/file.hankcs.com/corpus

# %%
result = HanLP("我买了三本书和两个苹果")
print(result)
# Out:
# {
#   "tok/fine": [
#     "我",
#     "买",
#     "了",
#     "三",
#     "本",
#     "书",
#     "和",
#     "两",
#     "个",
#     "苹果"
#   ],
#   "tok/coarse": [
#     "我",
#     "买",
#     "了",
#     "三",
#     "本",
#     "书",
#     "和",
#     "两",
#     "个",
#     "苹果"
#   ],
#   "pos/ctb": [
#     "PN",
#     "VV",
#     "AS",
#     "CD",
#     "M",
#     "NN",
#     "CC",
#     "CD",
#     "M",
#     "NN"
#   ],
#   "pos/pku": [
#     "r",
#     "v",
#     "u",
#     "m",
#     "q",
#     "n",
#     "c",
#     "m",
#     "q",
#     "n"
#   ],
#   "pos/863": [
#     "r",
#     "v",
#     "u",
#     "m",
#     "q",
#     "n",
#     "c",
#     "m",
#     "q",
#     "n"
#   ],
#   "ner/msra": [
#     ["三", "INTEGER", 3, 4],
#     ["两", "INTEGER", 7, 8]
#   ],
#   "ner/pku": [],
#   "ner/ontonotes": [
#     ["三", "CARDINAL", 3, 4],
#     ["两", "CARDINAL", 7, 8]
#   ],
#   "srl": [
#     [["我", "ARG0", 0, 1], ["买", "PRED", 1, 2], ["三本书和两个苹果", "ARG1", 3, 10]]
#   ],
#   "dep": [
#     [2, "nsubj"],
#     [0, "root"],
#     [2, "asp"],
#     [5, "nummod"],
#     [6, "clf"],
#     [10, "conj"],
#     [10, "cc"],
#     [9, "nummod"],
#     [10, "clf"],
#     [2, "dobj"]
#   ],
#   "sdp": [
#     [[2, "Agt"]],
#     [[5, "eSucc"]],
#     [[2, "mTime"]],
#     [[5, "Quan"]],
#     [[6, "Qp"]],
#     [[2, "Pat"]],
#     [[10, "mConj"]],
#     [[9, "Quan"]],
#     [[10, "Qp"]],
#     [[0, "Root"], [6, "eCoo"]]
#   ],
#   "con": [
#     "TOP",
#     [["IP", [["NP", [["PN", ["我"]]]], ["VP", [["VV", ["买"]], ["AS", ["了"]], ["NP", [["NP", [["QP", [["CD", ["三"]], ["CLP", [["M", ["本"]]]]]], ["NP", [["NN", ["书"]]]]]], ["CC", ["和"]], ["NP", [["QP", [["CD", ["两"]], ["CLP", [["M", ["个"]]]]]], ["NP", [["NN", ["苹果"]]]]]]]]]]]]]
#   ]
# }

# %%
import re
test = "我买了三本书！😊 Hello! (Nǐ hǎo)"
cleaned = re.sub(r'[^\u4e00-\u9fff\u3000-\u303f\uff00-\uffef]', '', test)
cleaned = re.sub(r'[\U00010000-\U0010ffff]', '', cleaned)
print(cleaned)
# Out:
# 我买了三本书！
